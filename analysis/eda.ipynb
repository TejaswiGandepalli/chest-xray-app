# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the CSV you just created
df = pd.read_csv("train_data.csv")
df.head()
# Out:
#                                             filename   label
# 0  IM-0003-0001_jpeg.rf.3d20928e15712caa61ab1511f...  NORMAL
# 1  IM-0003-0001_jpeg.rf.851dca81dbda058358d709231...  NORMAL
# 2  IM-0003-0001_jpeg.rf.a41818d6809bc1f19b6db2327...  NORMAL
# 3  IM-0006-0001_jpeg.rf.2117d282ff055b2ca6f2743fc...  NORMAL
# 4  IM-0006-0001_jpeg.rf.a7eb0c5e1d2a0333b69605577...  NORMAL

# %%
# Plot class distribution
sns.countplot(x="label", data=df)
plt.title("Normal vs Pneumonia Count")
plt.show()
